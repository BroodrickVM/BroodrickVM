# %% [markdown]
# <a href="https://colab.research.google.com/github/BroodrickVM/BroodrickVM/blob/main/Assignment5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np
import numpy as np
from scipy.interpolate import make_interp_spline
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.patches as mpatches

# %%
data = pd.read_csv(
    '/Crime_Incidents_in_2009.csv', parse_dates=True, index_col='REPORT_DAT'
)
display(data.head(3))
data = pd.read_csv(
    '/Crime_Incidents_in_2010.csv', parse_dates=True, index_col='REPORT_DAT'
)
display(data.head(3))
data = pd.read_csv(
    '/Crime_Incidents_in_2011.csv', parse_dates=True, index_col='REPORT_DAT'
)
display(data.head(3))
data = pd.read_csv(
    '/Crime_Incidents_in_2012.csv', parse_dates=True, index_col='REPORT_DAT'
)
display(data.head(3))
data = pd.read_csv(
    '/Crime_Incidents_in_2013.csv', parse_dates=True, index_col='REPORT_DAT'
)
display(data.head(3))
data = pd.read_csv(
    '/Crime_Incidents_in_2014.csv', parse_dates=True, index_col='REPORT_DAT'
)
display(data.head(3))
data = pd.read_csv(
    '/Crime_Incidents_in_2015.csv', parse_dates=True, index_col='REPORT_DAT'
)
display(data.head(3))
data = pd.read_csv(
    '/Crime_Incidents_in_2016.csv', parse_dates=True, index_col='REPORT_DAT'
)
display(data.head(3))
data = pd.read_csv(
    '/Crime_Incidents_in_2017.csv', parse_dates=True, index_col='REPORT_DAT'
)
display(data.head(3))
data = pd.read_csv(
    '/Crime_Incidents_in_2018.csv', parse_dates=True, index_col='REPORT_DAT'
)
display(data.head(3))
data = pd.read_csv(
    '/Crime_Incidents_in_2019.csv', parse_dates=True, index_col='REPORT_DAT'
)
display(data.head(3))
data = pd.read_csv(
    '/Crime_Incidents_in_2020.csv', parse_dates=True, index_col='REPORT_DAT'
)
display(data.head(3))
data = pd.read_csv(
    '/Crime_Incidents_in_2021.csv', parse_dates=True, index_col='REPORT_DAT'
)
display(data.head(3))
data = pd.read_csv(
    '/Crime_Incidents_in_2022.csv', parse_dates=True, index_col='REPORT_DAT'
)
display(data.head(3))
data = pd.read_csv(
    '/Crime_Incidents_in_2023.csv', parse_dates=True, index_col='REPORT_DAT'
)
display(data.head(3))
data = pd.read_csv(
    '/Crime_Incidents_in_2024.csv', parse_dates=True, index_col='REPORT_DAT'
)
display(data.head(3))
data = pd.read_csv(
    '/Crime_Incidents_in_2025.csv', parse_dates=True, index_col='REPORT_DAT'
)
display(data.head(3))
# Out:
#                                    X          Y      CCN     SHIFT  METHOD  \
# REPORT_DAT
# 2009-05-29 11:00:00+00:00 -76.942230  38.876704  9073036  MIDNIGHT  OTHERS
# 2009-05-29 13:55:00+00:00 -76.967311  38.918936  9073040       DAY  OTHERS
# 2009-05-29 14:00:00+00:00 -77.000937  38.962009  9073045       DAY  OTHERS
#
#                                        OFFENSE  \
# REPORT_DAT
# 2009-05-29 11:00:00+00:00  MOTOR VEHICLE THEFT
# 2009-05-29 13:55:00+00:00          THEFT/OTHER
# 2009-05-29 14:00:00+00:00          THEFT/OTHER
#
#                                                           BLOCK    XBLOCK  \
# REPORT_DAT
# 2009-05-29 11:00:00+00:00      700 - 899 BLOCK OF RIDGE ROAD SE  405013.0
# 2009-05-29 13:55:00+00:00      2300 - 3099 BLOCK OF V STREET NE  402835.0
# 2009-05-29 14:00:00+00:00  300  - 599 BLOCK OF ONEIDA STREET NE  399919.0
#
#                              YBLOCK  WARD  ... BLOCK_GROUP  CENSUS_TRACT  \
# REPORT_DAT                                 ...
# ...

# %%
import os

extracted_files = os.listdir('/content/')
crime_files = [f for f in extracted_files if 'Crime_Incidents_in_' in f and f.endswith('.csv')]

crime_dataframes = []
for file in crime_files:
    file_path = os.path.join('/content/', file)
    df = pd.read_csv(file_path, parse_dates=['REPORT_DAT'], index_col='REPORT_DAT')
    crime_dataframes.append(df)

print(f"Loaded {len(crime_dataframes)} dataframes.")
# Out:
# Loaded 0 dataframes.

# %%
import pandas as pd
import glob

# Option 1: If you want to read specific years manually
years = range(2009, 2026)  # 2009 through 2025 inclusive
dfs = []

for year in years:
    file_path = f'/Crime_Incidents_in_{year}.csv'
    df = pd.read_csv(file_path, parse_dates=True, index_col='REPORT_DAT')
    dfs.append(df)
    print(f"{year} shape:", df.shape)
    display(df.head(3))  # optional preview

# Combine into one big DataFrame
data = pd.concat(dfs)
print("Final shape:", data.shape)
display(data.head(10))
# Out:
# 2009 shape: (31354, 24)
#                                    X          Y      CCN     SHIFT  METHOD  \
# REPORT_DAT
# 2009-05-29 11:00:00+00:00 -76.942230  38.876704  9073036  MIDNIGHT  OTHERS
# 2009-05-29 13:55:00+00:00 -76.967311  38.918936  9073040       DAY  OTHERS
# 2009-05-29 14:00:00+00:00 -77.000937  38.962009  9073045       DAY  OTHERS
#
#                                        OFFENSE  \
# REPORT_DAT
# 2009-05-29 11:00:00+00:00  MOTOR VEHICLE THEFT
# 2009-05-29 13:55:00+00:00          THEFT/OTHER
# 2009-05-29 14:00:00+00:00          THEFT/OTHER
#
#                                                           BLOCK    XBLOCK  \
# REPORT_DAT
# 2009-05-29 11:00:00+00:00      700 - 899 BLOCK OF RIDGE ROAD SE  405013.0
# 2009-05-29 13:55:00+00:00      2300 - 3099 BLOCK OF V STREET NE  402835.0
# 2009-05-29 14:00:00+00:00  300  - 599 BLOCK OF ONEIDA STREET NE  399919.0
#
#                              YBLOCK  WARD  ... BLOCK_GROUP  CENSUS_TRACT  \
# ...

# %%
plt.figure(figsize=(12, 6))
plt.plot(crime_counts_by_year.index.year, crime_counts_by_year.values)
plt.title('Crime Incidents Over the Years (2009-2025)')
plt.xlabel('Year')
plt.ylabel('Number of Crime Incidents')
plt.grid(True)

plt.figure(figsize=(10, 6))
sns.barplot(x=crime_counts_by_ward.index, y=crime_counts_by_ward.values)
plt.title('Crime Incidents by Ward')
plt.xlabel('Ward')
plt.ylabel('Number of Crime Incidents')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-924903719.py in <cell line: 0>()
#       1 plt.figure(figsize=(12, 6))
# ----> 2 plt.plot(crime_counts_by_year.index.year, crime_counts_by_year.values)
#       3 plt.title('Crime Incidents Over the Years (2009-2025)')
#       4 plt.xlabel('Year')
#       5 plt.ylabel('Number of Crime Incidents')
#
# NameError: name 'crime_counts_by_year' is not defined

# %%
plt.figure(figsize=(12, 6))
plt.plot(crime_counts_by_year.index.year, crime_counts_by_year.values)
plt.title('Crime Incidents Over the Years (2009-2025)')
plt.xlabel('Year')
plt.ylabel('Number of Crime Incidents')
plt.grid(True)

plt.figure(figsize=(10, 6))
sns.barplot(x=crime_counts_by_ward.index, y=crime_counts_by_ward.values)
plt.title('Crime Incidents by Ward')
plt.xlabel('Ward')
plt.ylabel('Number of Crime Incidents')

plt.show()

# %%
crime_counts_by_year = data.resample('YE').size()
crime_counts_by_ward = data['WARD'].value_counts().sort_index()

# %%
plt.figure(figsize=(14, 7))
plt.plot(crime_counts_by_year.index.year, crime_counts_by_year.values)
plt.title('Annual Crime Incident Trends in Washington D.C. (2009-2025)', fontsize=16)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Number of Crime Incidents', fontsize=12)
plt.xticks(crime_counts_by_year.index.year, rotation=45, ha='right') # Rotate labels for readability
plt.grid(True)
plt.tight_layout() # Adjust layout to prevent labels overlapping

plt.figure(figsize=(12, 7))
sns.barplot(x=crime_counts_by_ward.index, y=crime_counts_by_ward.values, palette='viridis')
plt.title('Total Crime Incidents by Ward in Washington D.C. (2009-2025)', fontsize=16)
plt.xlabel('Ward', fontsize=12)
plt.ylabel('Number of Crime Incidents', fontsize=12)
plt.xticks(rotation=0) # Ensure ward labels are not rotated
plt.tight_layout() # Adjust layout

plt.show()
# Out:
# /tmp/ipython-input-1621635651.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=crime_counts_by_ward.index, y=crime_counts_by_ward.values, palette='viridis')

# %%
# Add markdown cell 1 above the first visualization (line plot)
from IPython.display import display, Markdown

markdown_text_line_plot = """
### Annual Crime Incident Trends (2009-2025)

This line plot illustrates the annual number of reported crime incidents in Washington D.C. from 2009 to 2025.
The plot shows a general trend with fluctuations over the years. There appears to be a peak in crime incidents around 2014, followed by a gradual decline and then an increase in recent years. This visualization helps to understand the overall temporal pattern of crime in the district.
"""
display(Markdown(markdown_text_line_plot))

plt.figure(figsize=(14, 7))
plt.plot(crime_counts_by_year.index.year, crime_counts_by_year.values)
plt.title('Annual Crime Incident Trends in Washington D.C. (2009-2025)', fontsize=16)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Number of Crime Incidents', fontsize=12)
plt.xticks(crime_counts_by_year.index.year, rotation=45, ha='right') # Rotate labels for readability
plt.grid(True)
plt.tight_layout() # Adjust layout to prevent labels overlapping
plt.show()

# Add markdown cell 2 above the second visualization (bar plot)
markdown_text_bar_plot = """
### Total Crime Incidents by Ward (2009-2025)

This bar plot displays the total number of reported crime incidents in each of Washington D.C.'s eight wards from 2009 to 2025.
The visualization clearly shows a variation in crime incident counts across different wards. Wards 1 and 2 appear to have the highest number of reported incidents, while Ward 3 consistently shows the lowest number. This highlights the spatial disparity in crime occurrences within the district.
"""
display(Markdown(markdown_text_bar_plot))

plt.figure(figsize=(12, 7))
sns.barplot(x=crime_counts_by_ward.index, y=crime_counts_by_ward.values, palette='viridis')
plt.title('Total Crime Incidents by Ward in Washington D.C. (2009-2025)', fontsize=16)
plt.xlabel('Ward', fontsize=12)
plt.ylabel('Number of Crime Incidents', fontsize=12)
plt.xticks(rotation=0) # Ensure ward labels are not rotated
plt.tight_layout() # Adjust layout

plt.show()
# Out:
# ### Annual Crime Incident Trends (2009-2025)
#
# This line plot illustrates the annual number of reported crime incidents in Washington D.C. from 2009 to 2025.
# The plot shows a general trend with fluctuations over the years. There appears to be a peak in crime incidents around 2014, followed by a gradual decline and then an increase in recent years. This visualization helps to understand the overall temporal pattern of crime in the district.
# ### Total Crime Incidents by Ward (2009-2025)
#
# This bar plot displays the total number of reported crime incidents in each of Washington D.C.'s eight wards from 2009 to 2025.
# The visualization clearly shows a variation in crime incident counts across different wards. Wards 1 and 2 appear to have the highest number of reported incidents, while Ward 3 consistently shows the lowest number. This highlights the spatial disparity in crime occurrences within the district.
# /tmp/ipython-input-1683768411.py:32: FutureWarning:
#
# ...
